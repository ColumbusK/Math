# %%
import numpy as np
import matplotlib.pyplot as plt
import math
plt.style.use('ggplot')

# %%
def expon2(x):
  return x**2


def expon3(x):
  a = 3
  return x**3


def root2(x):
  return np.sqrt(x)

def polynomial2(x):
  return 4*x**2 + 2*x - 2

x = np.linspace(-2, 2)
# print(x)
y = expon3(x)
# print(y)

fig, ax = plt.subplots(1)
print(fig, ax)
ax.plot([-3, 3], [0, 0], linestyle='--', c='gray')
ax.plot([0, 0], [-20, 20], linestyle='--', c='gray')
ax.plot(x, expon2(x))
ax.plot(x, expon3(x))
ax.plot(x, root2(x))
ax.plot(x, polynomial2(x))
# Out:
# Figure(576x396) AxesSubplot(0.125,0.125;0.775x0.755)
# <ipython-input-71-83fc51e04ba9>:11: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(x)
