# %%
import numpy as np
import matplotlib.pyplot as plt
import math
plt.style.use('ggplot')

# %%
def expon2(x):
  return x**2


def expon3(x):
  a = 3
  return x**3


def root2(x):
  return np.sqrt(x)

def polynomial2(x):
  return 4*x**2 + 2*x - 2

x = np.linspace(-2, 2)
# print(x)
y = expon3(x)
# print(y)

fig, ax = plt.subplots(1)
print(fig, ax)
ax.plot([-3, 3], [0, 0], linestyle='--', c='gray')
ax.plot([0, 0], [-20, 20], linestyle='--', c='gray')
ax.plot(x, expon2(x))
ax.plot(x, expon3(x))
ax.plot(x, root2(x))
ax.plot(x, polynomial2(x))
# Out:
# Figure(432x288) AxesSubplot(0.125,0.125;0.775x0.755)
# <ipython-input-2-83fc51e04ba9>:11: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(x)

# %%
# 练习
# 1. y = x^3 - 2x^2 -3x + 4
def func1(x):
  return x**3 - 2*x**2 - 3*x + 4

nx = np.linspace(-2, 3)

fig, ax = plt.subplots()
ax.plot([-3, 3], [0, 0], linestyle='--', c='gray')
ax.plot([0, 0], [-20, 20], linestyle='--', c='gray')
ax.set_ylim(-10, 10)
l1, = ax.plot(nx, func1(nx))
ax.annotate('func1', xy=(-1,3))
# Out:
# Text(-1, 3, 'func1')
